# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from matplotlib import ticker

# Tải tập dữ liệu chứng khoán
data = pd.read_csv('./Data/CTLT.csv')

# %%
data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-04-07  109.879997  113.489998  109.559998  112.750000  112.750000
# 1    2022-04-08  112.669998  113.180000  110.419998  110.709999  110.709999
# 2    2022-04-11  109.580002  110.000000  106.610001  107.050003  107.050003
# 3    2022-04-12  105.980003  107.099998   99.589996  100.059998  100.059998
# 4    2022-04-13   99.769997  101.919998   99.769997  100.879997  100.879997
# ..          ...         ...         ...         ...         ...         ...
# 246  2023-03-31   65.080002   66.000000   64.510002   65.709999   65.709999
# 247  2023-04-03   64.650002   65.059998   62.459999   62.919998   62.919998
# 248  2023-04-04   63.000000   63.740002   62.220001   62.250000   62.250000
# 249  2023-04-05   61.599998   62.430000   61.060001   61.619999   61.619999
# 250  2023-04-06   61.540001   65.635002   60.900002   64.949997   64.949997
#
#       Volume
# 0     750900
# 1     957300
# 2     820400
# 3    1824800
# 4     875500
# ..       ...
# 246  1069900
# 247  1708200
# 248  1435100
# 249  1471200
# 250  1854500
#
# [251 rows x 7 columns]

# %%
# Thư viện vẽ đồ thị
formatter = ticker.StrMethodFormatter('${x:,.0f}')

title = 'Bitcoin Price'
ylabel = 'USD'
xlabel = 'Date'

ax = data['Close'].plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %%
X = data[['Open', 'High', 'Low', 'Volume']].values
y = data['Close'].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Dense(64, input_dim=4, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 7/7 [==============================] - 3s 99ms/step - loss: 6644.0161 - val_loss: 6832.1245
# Epoch 2/50
# 7/7 [==============================] - 0s 16ms/step - loss: 6586.6367 - val_loss: 6779.7119
# Epoch 3/50
# 7/7 [==============================] - 0s 15ms/step - loss: 6531.3706 - val_loss: 6728.3813
# Epoch 4/50
# 7/7 [==============================] - 0s 15ms/step - loss: 6477.4902 - val_loss: 6677.0747
# Epoch 5/50
# 7/7 [==============================] - 0s 15ms/step - loss: 6421.1011 - val_loss: 6618.8706
# Epoch 6/50
# 7/7 [==============================] - 0s 14ms/step - loss: 6354.6807 - val_loss: 6547.8237
# Epoch 7/50
# 7/7 [==============================] - 0s 14ms/step - loss: 6276.4785 - val_loss: 6461.6265
# Epoch 8/50
# 7/7 [==============================] - 0s 14ms/step - loss: 6180.0186 - val_loss: 6361.4087
# Epoch 9/50
# 7/7 [==============================] - 0s 15ms/step - loss: 6069.2207 - val_loss: 6240.0723
# Epoch 10/50
# 7/7 [==============================] - 0s 20ms/step - loss: 5935.3989 - val_loss: 6092.5737
# Epoch 11/50
# 7/7 [==============================] - 0s 16ms/step - loss: 5771.4907 - val_loss: 5914.5991
# Epoch 12/50
# 7/7 [==============================] - 0s 17ms/step - loss: 5576.6548 - val_loss: 5709.1699
# Epoch 13/50
# 7/7 [==============================] - 0s 15ms/step - loss: 5351.8320 - val_loss: 5480.1978
# Epoch 14/50
# 7/7 [==============================] - 0s 15ms/step - loss: 5108.8652 - val_loss: 5221.9399
# Epoch 15/50
# 7/7 [==============================] - 0s 15ms/step - loss: 4840.7363 - val_loss: 4936.0361
# Epoch 16/50
# 7/7 [==============================] - 0s 17ms/step - loss: 4541.2344 - val_loss: 4633.2124
# Epoch 17/50
# 7/7 [==============================] - 0s 16ms/step - loss: 4225.3755 - val_loss: 4316.5151
# Epoch 18/50
# 7/7 [==============================] - 0s 15ms/step - loss: 3899.3054 - val_loss: 3978.9521
# Epoch 19/50
# 7/7 [==============================] - 0s 14ms/step - loss: 3565.7334 - val_loss: 3631.5857
# Epoch 20/50
# 7/7 [==============================] - 0s 14ms/step - loss: 3220.2837 - val_loss: 3289.7305
# Epoch 21/50
# 7/7 [==============================] - 0s 14ms/step - loss: 2878.9497 - val_loss: 2947.3567
# Epoch 22/50
# 7/7 [==============================] - 0s 14ms/step - loss: 2544.6536 - val_loss: 2607.8201
# Epoch 23/50
# 7/7 [==============================] - 0s 14ms/step - loss: 2220.0007 - val_loss: 2291.6218
# Epoch 24/50
# 7/7 [==============================] - 0s 14ms/step - loss: 1935.6572 - val_loss: 1999.1100
# Epoch 25/50
# 7/7 [==============================] - 0s 30ms/step - loss: 1666.4597 - val_loss: 1742.0554
# Epoch 26/50
# 7/7 [==============================] - 0s 24ms/step - loss: 1437.9564 - val_loss: 1513.3441
# Epoch 27/50
# 7/7 [==============================] - 0s 16ms/step - loss: 1245.6881 - val_loss: 1319.0095
# Epoch 28/50
# 7/7 [==============================] - 0s 14ms/step - loss: 1083.8954 - val_loss: 1163.5706
# Epoch 29/50
# 7/7 [==============================] - 0s 14ms/step - loss: 958.3700 - val_loss: 1038.5762
# Epoch 30/50
# 7/7 [==============================] - 0s 14ms/step - loss: 860.0458 - val_loss: 941.8148
# Epoch 31/50
# 7/7 [==============================] - 0s 15ms/step - loss: 786.0070 - val_loss: 866.9585
# Epoch 32/50
# 7/7 [==============================] - 0s 14ms/step - loss: 731.6467 - val_loss: 809.4487
# Epoch 33/50
# 7/7 [==============================] - 0s 15ms/step - loss: 689.9932 - val_loss: 767.8122
# Epoch 34/50
# 7/7 [==============================] - 0s 15ms/step - loss: 661.0996 - val_loss: 735.1899
# Epoch 35/50
# 7/7 [==============================] - 0s 15ms/step - loss: 639.7592 - val_loss: 708.9874
# Epoch 36/50
# 7/7 [==============================] - 0s 14ms/step - loss: 622.6198 - val_loss: 687.6052
# Epoch 37/50
# 7/7 [==============================] - 0s 15ms/step - loss: 608.1139 - val_loss: 668.5041
# Epoch 38/50
# 7/7 [==============================] - 0s 16ms/step - loss: 594.1967 - val_loss: 650.3139
# Epoch 39/50
# 7/7 [==============================] - 0s 17ms/step - loss: 581.5169 - val_loss: 632.3480
# Epoch 40/50
# 7/7 [==============================] - 0s 15ms/step - loss: 567.9122 - val_loss: 617.9435
# Epoch 41/50
# 7/7 [==============================] - 0s 16ms/step - loss: 556.0913 - val_loss: 604.7314
# Epoch 42/50
# 7/7 [==============================] - 0s 30ms/step - loss: 543.2242 - val_loss: 589.0656
# Epoch 43/50
# 7/7 [==============================] - 0s 22ms/step - loss: 530.4829 - val_loss: 571.4866
# Epoch 44/50
# 7/7 [==============================] - 0s 14ms/step - loss: 516.5149 - val_loss: 553.8914
# Epoch 45/50
# 7/7 [==============================] - 0s 22ms/step - loss: 503.3238 - val_loss: 536.0739
# Epoch 46/50
# 7/7 [==============================] - 0s 15ms/step - loss: 489.7916 - val_loss: 518.2678
# Epoch 47/50
# 7/7 [==============================] - 0s 16ms/step - loss: 475.5412 - val_loss: 500.7289
# Epoch 48/50
# 7/7 [==============================] - 0s 16ms/step - loss: 462.5877 - val_loss: 481.3987
# Epoch 49/50
# 7/7 [==============================] - 0s 16ms/step - loss: 448.3496 - val_loss: 464.0312
# Epoch 50/50
# 7/7 [==============================] - 0s 15ms/step - loss: 434.2072 - val_loss: 448.7191

# %%
y_pred = model.predict(X_test)
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print("RMSE:", rmse)
# Out:
# 2/2 [==============================] - 0s 6ms/step
# RMSE: 37.54322830107388

# %%
import matplotlib.pyplot as plt

plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 7/7 [==============================] - 0s 50ms/step - loss: 420.4351 - val_loss: 432.5422
# Epoch 2/50
# 7/7 [==============================] - 0s 28ms/step - loss: 407.2021 - val_loss: 415.6046
# Epoch 3/50
# 7/7 [==============================] - 0s 24ms/step - loss: 393.4255 - val_loss: 399.4118
# Epoch 4/50
# 7/7 [==============================] - 0s 24ms/step - loss: 380.2345 - val_loss: 383.1394
# Epoch 5/50
# 7/7 [==============================] - 0s 21ms/step - loss: 367.3764 - val_loss: 367.6998
# Epoch 6/50
# 7/7 [==============================] - 0s 37ms/step - loss: 354.4325 - val_loss: 352.4616
# Epoch 7/50
# 7/7 [==============================] - 0s 27ms/step - loss: 341.8408 - val_loss: 337.9357
# Epoch 8/50
# 7/7 [==============================] - 0s 23ms/step - loss: 329.7751 - val_loss: 324.0068
# Epoch 9/50
# 7/7 [==============================] - 0s 29ms/step - loss: 318.1611 - val_loss: 310.7733
# Epoch 10/50
# 7/7 [==============================] - 0s 14ms/step - loss: 307.2472 - val_loss: 297.1681
# Epoch 11/50
# 7/7 [==============================] - 0s 20ms/step - loss: 296.2409 - val_loss: 284.3829
# Epoch 12/50
# 7/7 [==============================] - 0s 15ms/step - loss: 285.8292 - val_loss: 272.1110
# Epoch 13/50
# 7/7 [==============================] - 0s 17ms/step - loss: 275.7435 - val_loss: 260.1352
# Epoch 14/50
# 7/7 [==============================] - 0s 15ms/step - loss: 266.0681 - val_loss: 249.0450
# Epoch 15/50
# 7/7 [==============================] - 0s 16ms/step - loss: 256.2200 - val_loss: 239.0142
# Epoch 16/50
# 7/7 [==============================] - 0s 18ms/step - loss: 247.3275 - val_loss: 229.0271
# Epoch 17/50
# 7/7 [==============================] - 0s 17ms/step - loss: 238.1562 - val_loss: 219.4244
# Epoch 18/50
# 7/7 [==============================] - 0s 19ms/step - loss: 229.4739 - val_loss: 209.8594
# Epoch 19/50
# 7/7 [==============================] - 0s 19ms/step - loss: 220.9058 - val_loss: 200.7800
# Epoch 20/50
# 7/7 [==============================] - 0s 26ms/step - loss: 212.9430 - val_loss: 192.0672
# Epoch 21/50
# 7/7 [==============================] - 0s 38ms/step - loss: 205.2653 - val_loss: 183.3446
# Epoch 22/50
# 7/7 [==============================] - 0s 15ms/step - loss: 197.2798 - val_loss: 175.8648
# Epoch 23/50
# 7/7 [==============================] - 0s 14ms/step - loss: 189.8270 - val_loss: 168.3738
# Epoch 24/50
# 7/7 [==============================] - 0s 16ms/step - loss: 182.8184 - val_loss: 161.1241
# Epoch 25/50
# 7/7 [==============================] - 0s 15ms/step - loss: 176.4741 - val_loss: 154.3017
# Epoch 26/50
# 7/7 [==============================] - 0s 18ms/step - loss: 169.9935 - val_loss: 147.7119
# Epoch 27/50
# 7/7 [==============================] - 0s 18ms/step - loss: 163.9671 - val_loss: 141.3315
# Epoch 28/50
# 7/7 [==============================] - 0s 16ms/step - loss: 158.0731 - val_loss: 135.0856
# Epoch 29/50
# 7/7 [==============================] - 0s 21ms/step - loss: 152.1961 - val_loss: 129.3686
# Epoch 30/50
# 7/7 [==============================] - 0s 17ms/step - loss: 146.6120 - val_loss: 124.1300
# Epoch 31/50
# 7/7 [==============================] - 0s 19ms/step - loss: 141.5674 - val_loss: 118.9461
# Epoch 32/50
# 7/7 [==============================] - 0s 15ms/step - loss: 136.2730 - val_loss: 114.4351
# Epoch 33/50
# 7/7 [==============================] - 0s 32ms/step - loss: 131.5404 - val_loss: 109.5574
# Epoch 34/50
# 7/7 [==============================] - 0s 25ms/step - loss: 127.1110 - val_loss: 104.6063
# Epoch 35/50
# 7/7 [==============================] - 0s 15ms/step - loss: 121.8708 - val_loss: 100.6632
# Epoch 36/50
# 7/7 [==============================] - 0s 15ms/step - loss: 117.7431 - val_loss: 96.6843
# Epoch 37/50
# 7/7 [==============================] - 0s 19ms/step - loss: 113.9051 - val_loss: 92.9444
# Epoch 38/50
# 7/7 [==============================] - 0s 15ms/step - loss: 109.7822 - val_loss: 89.2496
# Epoch 39/50
# 7/7 [==============================] - 0s 16ms/step - loss: 105.8250 - val_loss: 85.5280
# Epoch 40/50
# 7/7 [==============================] - 0s 19ms/step - loss: 102.1784 - val_loss: 81.9349
# Epoch 41/50
# 7/7 [==============================] - 0s 19ms/step - loss: 98.8026 - val_loss: 78.6566
# Epoch 42/50
# 7/7 [==============================] - 0s 16ms/step - loss: 95.3277 - val_loss: 75.6258
# Epoch 43/50
# 7/7 [==============================] - 0s 28ms/step - loss: 92.1030 - val_loss: 72.6164
# Epoch 44/50
# 7/7 [==============================] - 0s 17ms/step - loss: 89.0995 - val_loss: 69.7522
# Epoch 45/50
# 7/7 [==============================] - 0s 27ms/step - loss: 86.1978 - val_loss: 67.1223
# Epoch 46/50
# 7/7 [==============================] - 0s 79ms/step - loss: 83.1799 - val_loss: 64.6612
# Epoch 47/50
# 7/7 [==============================] - 0s 37ms/step - loss: 80.4425 - val_loss: 62.2104
# Epoch 48/50
# 7/7 [==============================] - 0s 16ms/step - loss: 77.5177 - val_loss: 60.0759
# Epoch 49/50
# 7/7 [==============================] - 0s 18ms/step - loss: 74.9582 - val_loss: 57.8640
# Epoch 50/50
# 7/7 [==============================] - 0s 24ms/step - loss: 72.4275 - val_loss: 55.7387

# %%
error = y_pred - y_test

plt.hist(error, bins=50)
plt.xlabel('Prediction Error')
plt.ylabel('Count')
plt.show()
